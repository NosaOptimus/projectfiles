# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('fifa.csv')
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality                 club  ...   lwb   ldm  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15465 entries, 0 to 15464
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(17), int64(11), object(76)
# memory usage: 12.3+ MB

# %%
df.shape
# Out:
# (15465, 104)

# %%
df.isnull().sum()
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            1703
# lcb           1703
# cb            1703
# rcb           1703
# rb            1703
# Length: 104, dtype: int64

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
df.tail()
# Out:
#        sofifa_id                                         player_url  \
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#        short_name      long_name  age         dob  height_cm  weight_kg  \
# 15460   E. Redman   Ellis Redman   17  1996-09-26        187         81
# 15461  A. Collins  Aaron Collins   17  1997-06-01        178         57
# 15462    P. Żemło    Piotr Żemło   18  1995-07-10        190         76
# 15463   T. Davies     Tom Davies   22  1992-04-18        180         70
# 15464  P. Tisdale   Paul Tisdale   41  1973-01-14        175         72
#
#       nationality            club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
df
pd.options.display.max_columns = None
display(df)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
df1 = df.loc[df['power_shot_power']>=90]
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 df1 = df.loc[df['power_shot_power']>=90]
#       2 df1
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# ...

# %%
df.query('power_shot_power > 89')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df.query('power_shot_power > 89')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4111, in DataFrame.query(self, expr, inplace, **kwargs)
#    4109 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4110 kwargs["target"] = None
# -> 4111 res = self.eval(expr, **kwargs)
#    4113 try:
#    4114     result = self.loc[res]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4240, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4237     kwargs["target"] = self
#    4238 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4240 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\eval.py:350, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
# ...

# %%
df1 = pd.DataFrame({'power_shot_power': range(89,97)})
df1
# Out:
#    power_shot_power
# 0                89
# 1                90
# 2                91
# 3                92
# 4                93
# 5                94
# 6                95
# 7                96

# %%
df.sort_values('power_shot_power',ascending=False,inplace=True)

# %%
df['power_shot_power'].unique()
# Out:
# array(['96', '94+2', '94', '93-1', '93', '92', '91-1', '91', '90-5',
#        '90-2', '90-1', '90+2', '90', '89-1', '89+5', '89+1', '89', '88-3',
#        '88-1', '88', '87-1', '87+3', '87', '86-5', '86-2', '86-1', '86+2',
#        '86+1', '86', '85-4', '85-3', '85-2', '85-1', '85+4', '85+2',
#        '85+1', '85', '84-1', '84+9', '84+3', '84+2', '84+1', '84', '83-7',
#        '83-1', '83+6', '83+5', '83+4', '83+3', '83+2', '83+1', '83',
#        '82-3', '82-2', '82-1', '82+4', '82+2', '82+1', '82', '81-4',
#        '81-2', '81-11', '81-1', '81+8', '81+5', '81+4', '81+3', '81+14',
#        '81+12', '81+1', '81', '80-5', '80-3', '80-2', '80-1', '80+8',
#        '80+7', '80+6', '80+3', '80+2', '80+12', '80+1', '80', '79-5',
#        '79-3', '79-2', '79-1', '79+8', '79+7', '79+3', '79+21', '79+2',
#        '79+10', '79+1', '79', '78-5', '78-4', '78-3', '78-2', '78-1',
#        '78+9', '78+5', '78+4', '78+3', '78+22', '78+2', '78+19', '78+1',
# ...

# %%
plt.figure(figsize=(3,9))
plt.bar(x=df['short_name'],
       height= df[pd.DataFrame({'power_shot_power': range(89,97)})])
plt.xticks(rotation = 45)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 plt.figure(figsize=(3,9))
#       2 plt.bar(x=df['short_name'],
# ----> 3        height= df[pd.DataFrame({'power_shot_power': range(89,97)})])
#       4 plt.xticks(rotation = 45)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3492, in DataFrame.__getitem__(self, key)
#    3490 # Do we have a (boolean) DataFrame?
#    3491 if isinstance(key, DataFrame):
# -> 3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
# ...

# %%
df2
